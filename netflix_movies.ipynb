# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import re

import warnings
import os

warnings.filterwarnings('ignore')

# %%
credits = pd.read_csv('./data/credits.csv')
titles = pd.read_csv('./data/titles.csv')

# %%
df_credits = pd.DataFrame(credits)
df_titles = pd.DataFrame(titles)
print(df_credits.shape)
print(df_titles.shape)
# Out:
# (77801, 5)
# (5850, 15)

# %%
df_credits.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
df_titles.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# ...

# %%
df_titles.sort_values(by='tmdb_popularity',axis=0)
# Out:
#              id                                title   type  \
# 1061   tm132675  100 Things to Do Before High School  MOVIE
# 249    tm997728          Blade Runner: The Final Cut  MOVIE
# 2483   tm995893                         The Crossing  MOVIE
# 2433    ts94470                            Relatable   SHOW
# 2189    ts82375                 Beyblade Burst Turbo   SHOW
# ...         ...                                  ...    ...
# 5807  tm1011248                             30 March  MOVIE
# 5810  tm1225897                           Social Man  MOVIE
# 5823  tm1099342                      Devdas Brothers  MOVIE
# 5844  tm1074617        Bling Empire - The Afterparty  MOVIE
# 5846   tm898842                          C/O Kaadhal  MOVIE
#
#                                             description  release_year  \
# 1061  With the pressures of high school in their nea...          2014
# 249   Visually spectacular, intensely action-packed ...          2007
# ...

# %%
df_titles.isnull().any()
# Out:
# id                      False
# title                    True
# type                    False
# description              True
# release_year            False
# age_certification        True
# runtime                 False
# genres                  False
# production_countries    False
# seasons                  True
# imdb_id                  True
# imdb_score               True
# imdb_votes               True
# tmdb_popularity          True
# tmdb_score               True
# dtype: bool

# %%
df_titles = df_titles.dropna(axis=0,how='any')
df_titles.shape
# Out:
# (1667, 15)

# %%
df_credits.isnull().any()
# Out:
# person_id    False
# id           False
# name         False
# character     True
# role         False
# dtype: bool

# %%
df_credits = df_credits.dropna(axis=0,how='any')
df_credits.shape
# Out:
# (68029, 5)

# %%
df_credits.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
df_titles.head()
# Out:
#          id                             title  type  \
# 5   ts22164      Monty Python's Flying Circus  SHOW
# 26  ts45948  Monty Python's Fliegender Zirkus  SHOW
# 35  ts20681                          Seinfeld  SHOW
# 44  ts22082                      Knight Rider  SHOW
# 45  ts21715                  Thomas & Friends  SHOW
#
#                                           description  release_year  \
# 5   A British sketch comedy series with the shows ...          1969
# 26  Monty Python's Fliegender Zirkus consisted of ...          1972
# 35  A stand-up comedian and his three offbeat frie...          1989
# 44  Michael Long, an undercover police officer, is...          1982
# 45  Thomas & Friends is a British children's telev...          1984
#
#    age_certification  runtime  \
# 5              TV-14       30
# 26             TV-MA       43
# 35             TV-PG       24
# 44             TV-PG       51
# 45              TV-Y       10
#
# ...

# %%
df_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1667 entries, 5 to 5831
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1667 non-null   object
#  1   title                 1667 non-null   object
#  2   type                  1667 non-null   object
#  3   description           1667 non-null   object
#  4   release_year          1667 non-null   int64
#  5   age_certification     1667 non-null   object
#  6   runtime               1667 non-null   int64
#  7   genres                1667 non-null   object
#  8   production_countries  1667 non-null   object
#  9   seasons               1667 non-null   float64
#  10  imdb_id               1667 non-null   object
#  11  imdb_score            1667 non-null   float64
#  12  imdb_votes            1667 non-null   float64
#  13  tmdb_popularity       1667 non-null   float64
#  14  tmdb_score            1667 non-null   float64
# ...

# %%
df_titles = df_titles.astype({'seasons': 'Int64'})
df_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1667 entries, 5 to 5831
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1667 non-null   object
#  1   title                 1667 non-null   object
#  2   type                  1667 non-null   object
#  3   description           1667 non-null   object
#  4   release_year          1667 non-null   int64
#  5   age_certification     1667 non-null   object
#  6   runtime               1667 non-null   int64
#  7   genres                1667 non-null   object
#  8   production_countries  1667 non-null   object
#  9   seasons               1667 non-null   Int64
#  10  imdb_id               1667 non-null   object
#  11  imdb_score            1667 non-null   float64
#  12  imdb_votes            1667 non-null   float64
#  13  tmdb_popularity       1667 non-null   float64
#  14  tmdb_score            1667 non-null   float64
# ...

# %%
df_titles.head()
# Out:
#          id                             title  type  \
# 5   ts22164      Monty Python's Flying Circus  SHOW
# 26  ts45948  Monty Python's Fliegender Zirkus  SHOW
# 35  ts20681                          Seinfeld  SHOW
# 44  ts22082                      Knight Rider  SHOW
# 45  ts21715                  Thomas & Friends  SHOW
#
#                                           description  release_year  \
# 5   A British sketch comedy series with the shows ...          1969
# 26  Monty Python's Fliegender Zirkus consisted of ...          1972
# 35  A stand-up comedian and his three offbeat frie...          1989
# 44  Michael Long, an undercover police officer, is...          1982
# 45  Thomas & Friends is a British children's telev...          1984
#
#    age_certification  runtime  \
# 5              TV-14       30
# 26             TV-MA       43
# 35             TV-PG       24
# 44             TV-PG       51
# 45              TV-Y       10
#
# ...

# %% [markdown]
# # ideas
#
# - tablas con los generos de las peliculas
# - más valoradas de ese genero de peliculas
# - que tipos de programas hay
# - cuantas peliculas en que años
# - las que no son series cambiarle el nan por 0

# %%
import ast

genres = df_titles['genres']
type(genres)
genres = genres.to_numpy()
genres
type(genres)
# np.char.strip(genres,"'[]")
# Out:
# numpy.ndarray
